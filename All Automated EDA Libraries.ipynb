# %% [markdown]
# # D Tale Library

# %%
# !pip install dtale
# Out:
# Requirement already satisfied: dtale in c:\users\shalm\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: dash-colorscales in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (0.0.4)
# Requirement already satisfied: dash-daq in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (0.5.0)
# Requirement already satisfied: Flask-Compress in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (1.14)
# Requirement already satisfied: future>=0.14.0 in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (0.18.3)
# Requirement already satisfied: kaleido in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: missingno in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (0.4.2)
# Requirement already satisfied: pandas in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (2.2.1)
# Requirement already satisfied: squarify in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (0.4.3)
# Requirement already satisfied: strsimpy in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: six in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (1.16.0)
# Requirement already satisfied: xlrd in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (4.12.2)
# Requirement already satisfied: certifi in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (2024.2.2)
# Requirement already satisfied: flask-ngrok in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (0.0.25)
# Requirement already satisfied: lz4 in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (4.3.2)
# Requirement already satisfied: cycler in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (0.11.0)
# Requirement already satisfied: dash-bootstrap-components<=1.3.1 in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (1.3.1)
# Requirement already satisfied: dash in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (2.16.0)
# Requirement already satisfied: seaborn in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (0.12.2)
# Requirement already satisfied: statsmodels in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (0.14.0)
# Requirement already satisfied: werkzeug in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (2.2.3)
# Requirement already satisfied: networkx in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (3.1)
# Requirement already satisfied: scikit-learn in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (1.2.2)
# Requirement already satisfied: numpy in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (1.24.4)
# Requirement already satisfied: openpyxl!=3.2.0b1 in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (3.0.10)
# Requirement already satisfied: xarray in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (2023.6.0)
# Requirement already satisfied: et-xmlfile in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: plotly in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (5.9.0)
# Requirement already satisfied: Flask<2.3 in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (2.2.5)
# Requirement already satisfied: itsdangerous in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: requests in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (2.31.0)
# Requirement already satisfied: contourpy in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (1.2.0)
# Requirement already satisfied: matplotlib in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (3.7.4)
# Requirement already satisfied: scipy!=1.12.0rc1 in c:\users\shalm\anaconda3\lib\site-packages (from dtale) (1.11.4)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\shalm\anaconda3\lib\site-packages (from dash->dtale) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\shalm\anaconda3\lib\site-packages (from dash->dtale) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\shalm\anaconda3\lib\site-packages (from dash->dtale) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\shalm\anaconda3\lib\site-packages (from dash->dtale) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\shalm\anaconda3\lib\site-packages (from dash->dtale) (4.9.0)
# Requirement already satisfied: retrying in c:\users\shalm\anaconda3\lib\site-packages (from dash->dtale) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\shalm\anaconda3\lib\site-packages (from dash->dtale) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\shalm\anaconda3\lib\site-packages (from dash->dtale) (68.2.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\shalm\anaconda3\lib\site-packages (from Flask<2.3->dtale) (3.1.3)
# Requirement already satisfied: click>=8.0 in c:\users\shalm\anaconda3\lib\site-packages (from Flask<2.3->dtale) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\shalm\anaconda3\lib\site-packages (from plotly->dtale) (8.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\shalm\anaconda3\lib\site-packages (from werkzeug->dtale) (2.1.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shalm\anaconda3\lib\site-packages (from beautifulsoup4->dtale) (2.5)
# Requirement already satisfied: brotli in c:\users\shalm\anaconda3\lib\site-packages (from Flask-Compress->dtale) (1.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shalm\anaconda3\lib\site-packages (from matplotlib->dtale) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shalm\anaconda3\lib\site-packages (from matplotlib->dtale) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shalm\anaconda3\lib\site-packages (from matplotlib->dtale) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shalm\anaconda3\lib\site-packages (from matplotlib->dtale) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shalm\anaconda3\lib\site-packages (from matplotlib->dtale) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shalm\anaconda3\lib\site-packages (from matplotlib->dtale) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shalm\anaconda3\lib\site-packages (from pandas->dtale) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shalm\anaconda3\lib\site-packages (from pandas->dtale) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shalm\anaconda3\lib\site-packages (from requests->dtale) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shalm\anaconda3\lib\site-packages (from requests->dtale) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shalm\anaconda3\lib\site-packages (from requests->dtale) (2.0.7)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\shalm\anaconda3\lib\site-packages (from scikit-learn->dtale) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\shalm\anaconda3\lib\site-packages (from scikit-learn->dtale) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\shalm\anaconda3\lib\site-packages (from statsmodels->dtale) (0.5.3)
# Requirement already satisfied: colorama in c:\users\shalm\anaconda3\lib\site-packages (from click>=8.0->Flask<2.3->dtale) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\shalm\anaconda3\lib\site-packages (from importlib-metadata->dash->dtale) (3.17.0)

# %%
import seaborn as sns

df=sns.load_dataset('titanic')

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
import dtale
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://MSI:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Sweetviz Library

# %%
# !pip install sweetviz

# %%
import sweetviz as sv
report=sv.analyze(df)
report.show_html('sweet_report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report sweet_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # Autoviz Library

# %%
# !pip install autoviz

# %%
from autoviz.AutoViz_Class import AutoViz_Class

AV = AutoViz_Class()
# %matplotlib inline
# Out:
# Imported v0.1.806. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
filename = "titanic_dataset.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg",
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
)
# Out:
# Shape of your Data Set loaded: (891, 15)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     15 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# There are 107 duplicate rows in your dataset
#     Alert: Dropping duplicate rows can sometimes cause your column data types to change to object!
#     All variables classified into correct types.
# <style type="text/css">
# #T_3b753_row0_col0, #T_3b753_row0_col2, #T_3b753_row0_col3, #T_3b753_row0_col4, #T_3b753_row0_col5, #T_3b753_row1_col0, #T_3b753_row1_col2, #T_3b753_row1_col3, #T_3b753_row1_col4, #T_3b753_row1_col5, #T_3b753_row2_col0, #T_3b753_row2_col2, #T_3b753_row2_col3, #T_3b753_row2_col4, #T_3b753_row2_col5
outliers greater than upper bound (2.50) or lower than lower bound(-1.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_3b753_level0_row6" class="row_heading level0 row6" >fare</th>
#       <td id="T_3b753_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_3b753_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_3b753_row6_col2" class="data row6 col2" >NA</td>
#       <td id="T_3b753_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_3b753_row6_col4" class="data row6 col4" >512.329200</td>
#       <td id="T_3b753_row6_col5" class="data row6 col5" >Column has 102 outliers greater than upper bound (73.20) or lower than lower bound(-31.04). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_3b753_level0_row7" class="row_heading level0 row7" >embarked</th>
#       <td id="T_3b753_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_3b753_row7_col1" class="data row7 col1" >0.255102</td>
#       <td id="T_3b753_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_3b753_row7_col3" class="data row7 col3" ></td>
#       <td id="T_3b753_row7_col4" class="data row7 col4" ></td>
#       <td id="T_3b753_row7_col5" class="data row7 col5" >2 missing values. Impute them with mean, median, mode, or a constant value such as 123., Mixed dtypes: has 2 different data types:  object, float,</td>
#     </tr>
#     <tr>
#       <th id="T_3b753_level0_row8" class="row_heading level0 row8" >class</th>
#       <td id="T_3b753_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_3b753_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_3b753_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_3b753_row8_col3" class="data row8 col3" ></td>
#       <td id="T_3b753_row8_col4" class="data row8 col4" ></td>
#       <td id="T_3b753_row8_col5" class="data row8 col5" >No issue</td>
#     </tr>
#     <tr>
# Number of All Scatter Plots = 3
# Could not draw Distribution Plot
# All Plots done
# Time to run AutoViz = 5 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %%
import seaborn as sns

# Load Titanic dataset from Seaborn
titanic_df = sns.load_dataset('titanic')

# Display the first few rows of the dataset
print(titanic_df.head())

# Save the dataset to a CSV file
titanic_df.to_csv('titanic_dataset.csv', index=False)

print("Dataset saved to 'titanic_dataset.csv'")
# Out:
#    survived  pclass   sex     age  sibsp  parch   fare   embarked class   \
# 0      0        3      male  22.0    1      0     7.2500     S     Third
# 1      1        1    female  38.0    1      0    71.2833     C     First
# 2      1        3    female  26.0    0      0     7.9250     S     Third
# 3      1        1    female  35.0    1      0    53.1000     S     First
# 4      0        3      male  35.0    0      0     8.0500     S     Third
#
#    who    adult_male deck embark_town  alive  alone
# 0    man      True    NaN  Southampton    no  False
# 1  woman     False      C    Cherbourg   yes  False
# 2  woman     False    NaN  Southampton   yes   True
# 3  woman     False      C  Southampton   yes  False
# 4    man      True    NaN  Southampton    no   True
# Dataset saved to 'titanic_dataset.csv'

# %% [markdown]
# # pandas profiling Library

# %%
# !pip install pandas-profiling

# %%
import seaborn as sns 
df1=sns.load_dataset('tips')

# %%
df1.head()
# Out:
#    total_bill   tip   sex   smoker day    time   size
# 0     16.99    1.01  Female   No    Sun  Dinner    2
# 1     10.34    1.66    Male   No    Sun  Dinner    3
# 2     21.01    3.50    Male   No    Sun  Dinner    3
# 3     23.68    3.31    Male   No    Sun  Dinner    2
# 4     24.59    3.61  Female   No    Sun  Dinner    4

# %%
from pandas_profiling import ProfileReport
profile=ProfileReport(df1,explorative=True)
profile.to_file('PandasProfilingOutput.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 profile=ProfileReport(df1,explorative=True)
#       3 profile.to_file('PandasProfilingOutput.html')
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)
#      15         A ProfileReport of the DataFrame.
#      16     """
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\profile_report.py:11
#       9 import yaml
#      10 from tqdm.auto import tqdm
# ---> 11 from visions import VisionsTypeset
#      13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#
# File ~\anaconda3\Lib\site-packages\visions\__init__.py:4
#       1 """Core functionality"""
#       3 from visions import types, typesets, utils
# ----> 4 from visions.backends import *
#       5 from visions.declarative import create_type
#       6 from visions.functional import (
#       7     cast_to_detected,
#       8     cast_to_inferred,
#       9     detect_type,
#      10     infer_type,
#      11 )
#
# File ~\anaconda3\Lib\site-packages\visions\backends\__init__.py:9
#       6 try:
#       7     import pandas as pd
# ----> 9     import visions.backends.pandas
#      10     from visions.backends.pandas.test_utils import pandas_version
#      12     if pandas_version[0] < 1:
#
# File ~\anaconda3\Lib\site-packages\visions\backends\pandas\__init__.py:2
#       1 import visions.backends.pandas.traversal
# ----> 2 import visions.backends.pandas.types
#
# File ~\anaconda3\Lib\site-packages\visions\backends\pandas\types\__init__.py:3
#       1 import visions.backends.pandas.types.boolean
#       2 import visions.backends.pandas.types.categorical
# ----> 3 import visions.backends.pandas.types.complex
#       4 import visions.backends.pandas.types.count
#       5 import visions.backends.pandas.types.date
#
# File ~\anaconda3\Lib\site-packages\visions\backends\pandas\types\complex.py:7
#       5 from visions.backends.pandas.series_utils import series_not_empty, series_not_sparse
#       6 from visions.backends.pandas.types.float import string_is_float
# ----> 7 from visions.backends.shared.parallelization_engines import pandas_apply
#       8 from visions.types.complex import Complex
#       9 from visions.types.string import String
#
# File ~\anaconda3\Lib\site-packages\visions\backends\shared\__init__.py:1
# ----> 1 from . import nan_handling, parallelization_engines, utilities
#
# File ~\anaconda3\Lib\site-packages\visions\backends\shared\nan_handling.py:34
#      30 # TODO: There are optimizations here, just have to define precisely the desired missing ruleset in the
#      31 # generated jit
#      32 if has_numba:
# ---> 34     @nb.generated_jit(nopython=True)
#      35     def is_missing(x):
#      36         """
#      37         Return True if the value is missing, False otherwise.
#      38         """
#      39         if isinstance(x, nb.types.Float):
#
# AttributeError: module 'numba' has no attribute 'generated_jit'

# %% [markdown]
# # Pandas Visual Analysis
#
# #### If the dataset is complex (ex : has many many categorical variables) this will not work greatly

# %%
# !pip install pandas_visual_analysis
# Out:
# Collecting pandas_visual_analysis
#   Downloading pandas_visual_analysis-0.0.4-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: setuptools>=49.2.0 in c:\users\shalm\anaconda3\lib\site-packages (from pandas_visual_analysis) (68.2.2)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\shalm\anaconda3\lib\site-packages (from pandas_visual_analysis) (2.2.1)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\shalm\anaconda3\lib\site-packages (from pandas_visual_analysis) (7.6.5)
# Requirement already satisfied: numpy>=1.19.1 in c:\users\shalm\anaconda3\lib\site-packages (from pandas_visual_analysis) (1.24.4)
# Requirement already satisfied: plotly>=4.10.0 in c:\users\shalm\anaconda3\lib\site-packages (from pandas_visual_analysis) (5.9.0)
# Requirement already satisfied: blinker>=1.4 in c:\users\shalm\anaconda3\lib\site-packages (from pandas_visual_analysis) (1.6.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (6.28.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (5.7.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (5.9.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (3.5.2)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (8.20.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shalm\anaconda3\lib\site-packages (from pandas>=1.1.0->pandas_visual_analysis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shalm\anaconda3\lib\site-packages (from pandas>=1.1.0->pandas_visual_analysis) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shalm\anaconda3\lib\site-packages (from pandas>=1.1.0->pandas_visual_analysis) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\shalm\anaconda3\lib\site-packages (from plotly>=4.10.0->pandas_visual_analysis) (8.2.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (1.6.0)
# Requirement already satisfied: packaging in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (23.1)
# Requirement already satisfied: psutil in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (6.3.3)
# Requirement already satisfied: decorator in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.0)
# Requirement already satisfied: colorama in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.4.6)
# Requirement already satisfied: fastjsonschema in c:\users\shalm\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\shalm\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (4.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\shalm\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1.0->pandas_visual_analysis) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\shalm\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (7.0.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\shalm\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\shalm\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\shalm\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\shalm\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\shalm\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (305.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\shalm\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\shalm\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\shalm\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\shalm\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.3)
# Requirement already satisfied: wcwidth in c:\users\shalm\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.5)
# Requirement already satisfied: executing in c:\users\shalm\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\shalm\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\shalm\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (4.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (3.1.3)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (7.10.0)
# Requirement already satisfied: overrides in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.14.1)
# Requirement already satisfied: pywinpty in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.58.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\shalm\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\shalm\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\shalm\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\shalm\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.9.6)
# Requirement already satisfied: requests>=2.31 in c:\users\shalm\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.31.0)
# Requirement already satisfied: idna>=2.8 in c:\users\shalm\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\shalm\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shalm\anaconda3\lib\site-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.1.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shalm\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shalm\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shalm\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2024.2.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\shalm\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\shalm\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.5.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\shalm\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis)
#   Downloading webcolors-1.13-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\shalm\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shalm\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.5)
# Requirement already satisfied: pycparser in c:\users\shalm\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\shalm\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.2.3)
# Downloading pandas_visual_analysis-0.0.4-py3-none-any.whl (34 kB)
# Downloading webcolors-1.13-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, fqdn, isoduration, pandas_visual_analysis
# Successfully installed fqdn-1.5.1 isoduration-20.11.0 pandas_visual_analysis-0.0.4 uri-template-1.3.0 webcolors-1.13

# %%
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
import seaborn as sns

# Get dataset names
dataset_names = set(sns.get_dataset_names())

# Print unique dataset names
print(dataset_names)
# Out:
# {'geyser', 'brain_networks', 'flights', 'dowjones', 'titanic', 'anscombe', 'healthexp', 'anagrams', 'taxis', 'exercise', 'penguins', 'car_crashes', 'mpg', 'seaice', 'dots', 'tips', 'planets', 'fmri', 'iris', 'attention', 'glue', 'diamonds'}

# %%
df=sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0       5.1          3.5           1.4          0.2      setosa
# 1       4.9          3.0           1.4          0.2      setosa
# 2       4.7          3.2           1.3          0.2      setosa
# 3       4.6          3.1           1.5          0.2      setosa
# 4       5.0          3.6           1.4          0.2      setosa

# %%
from pandas_visual_analysis import VisualAnalysis

# %%
VisualAnalysis(df)
# Out:
# VBox(children=(ToggleButtons(_dom_classes=('layout-4ffc8388a1f7478ba1f1f4b5e829893e',), description='Selection…

# %%
import ipywidgets as widgets
widgets.__version__
# Out:
# '7.6.5'

# %%
# !pip install ipywidgets==7.6.5
# Out:
# Requirement already satisfied: ipywidgets==7.6.5 in c:\users\shalm\anaconda3\lib\site-packages (7.6.5)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets==7.6.5) (6.28.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets==7.6.5) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets==7.6.5) (5.7.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets==7.6.5) (5.9.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets==7.6.5) (3.5.2)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets==7.6.5) (8.20.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets==7.6.5) (3.0.9)
# Requirement already satisfied: comm>=0.1.1 in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5) (1.6.0)
# Requirement already satisfied: packaging in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5) (23.1)
# Requirement already satisfied: psutil in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\shalm\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5) (6.3.3)
# Requirement already satisfied: decorator in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5) (0.2.0)
# Requirement already satisfied: colorama in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5) (0.4.6)
# Requirement already satisfied: fastjsonschema in c:\users\shalm\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\shalm\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5) (4.19.2)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\shalm\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (7.0.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\shalm\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.6.5) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\shalm\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\shalm\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\shalm\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\shalm\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.6.5) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.6.5) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.6.5) (305.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\shalm\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\shalm\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\shalm\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\shalm\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (0.2.3)
# Requirement already satisfied: wcwidth in c:\users\shalm\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets==7.6.5) (0.2.5)
# Requirement already satisfied: executing in c:\users\shalm\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.6.5) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\shalm\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.6.5) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\shalm\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.6.5) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (4.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (3.1.3)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (7.10.0)
# Requirement already satisfied: overrides in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (0.14.1)
# Requirement already satisfied: pywinpty in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (0.58.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\shalm\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\shalm\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\shalm\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\shalm\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (0.9.6)
# Requirement already satisfied: requests>=2.31 in c:\users\shalm\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\shalm\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.6.5) (1.16.0)
# Requirement already satisfied: idna>=2.8 in c:\users\shalm\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\shalm\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (1.3.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\shalm\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2023.3.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shalm\anaconda3\lib\site-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2.1.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\shalm\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\shalm\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (1.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shalm\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shalm\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shalm\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2024.2.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\shalm\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\shalm\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\shalm\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\shalm\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\shalm\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2.1)
# Requirement already satisfied: uri-template in c:\users\shalm\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\shalm\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\shalm\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shalm\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2.5)
# Requirement already satisfied: pycparser in c:\users\shalm\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\shalm\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5) (1.2.3)

# %%
# !pip install --upgrade ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\shalm\anaconda3\lib\site-packages (7.6.5)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting comm>=0.1.3 (from ipywidgets)
#   Downloading comm-0.2.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets) (8.20.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\shalm\anaconda3\lib\site-packages (from ipywidgets) (5.7.1)
# Collecting widgetsnbextension~=4.0.10 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.10 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\shalm\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\shalm\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\shalm\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in c:\users\shalm\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\shalm\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\shalm\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in c:\users\shalm\anaconda3\lib\site-packages (from asttokens->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.1.2-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/139.4 kB ? eta -:--:--
#    ----------------- ---------------------- 61.4/139.4 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 139.4/139.4 kB 1.7 MB/s eta 0:00:00
# Downloading comm-0.2.1-py3-none-any.whl (7.2 kB)
# Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl (215 kB)
#    ---------------------------------------- 0.0/215.0 kB ? eta -:--:--
#    -------------------------------- ------- 174.1/215.0 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 215.0/215.0 kB 4.4 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.3 MB 6.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.6/2.3 MB 5.4 MB/s eta 0:00:01
#    --------------- ------------------------ 0.9/2.3 MB 5.7 MB/s eta 0:00:01
#    -------------------- ------------------- 1.2/2.3 MB 5.9 MB/s eta 0:00:01
#    ------------------------- -------------- 1.5/2.3 MB 5.9 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------- -- 2.1/2.3 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 6.1 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, comm, ipywidgets
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.5.2
#     Uninstalling widgetsnbextension-3.5.2:
#       Successfully uninstalled widgetsnbextension-3.5.2
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 3.0.9
#     Uninstalling jupyterlab-widgets-3.0.9:
#       Successfully uninstalled jupyterlab-widgets-3.0.9
#   Attempting uninstall: comm
#     Found existing installation: comm 0.1.2
#     Uninstalling comm-0.1.2:
#       Successfully uninstalled comm-0.1.2
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.6.5
#     Uninstalling ipywidgets-7.6.5:
#       Successfully uninstalled ipywidgets-7.6.5
# Successfully installed comm-0.2.1 ipywidgets-8.1.2 jupyterlab-widgets-3.0.10 widgetsnbextension-4.0.10
